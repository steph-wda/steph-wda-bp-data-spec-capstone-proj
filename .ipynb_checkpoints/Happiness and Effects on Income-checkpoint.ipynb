# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import pearsonr, spearmanr

# %matplotlib inline

# %%
#loading data
raw_happy2015_df=pd.read_csv("world_happiness/2015.csv")
raw_happy2016_df=pd.read_csv("world_happiness/2016.csv")
raw_happy2017_df=pd.read_csv("world_happiness/2017.csv")
raw_happy2018_df=pd.read_csv("world_happiness/2018.csv")
raw_happy2019_df=pd.read_csv("world_happiness/2019.csv")

#creating copies to preserve orginal dataframes
happy2015_df=raw_happy2015_df.copy()
happy2016_df=raw_happy2016_df.copy()
happy2017_df=raw_happy2017_df.copy()
happy2018_df=raw_happy2018_df.copy()
happy2019_df=raw_happy2019_df.copy()

# %%
happy2015_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
happy2015_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
happy2016_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
#  12  Dystopia Residual              157 non-null    float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 16.1+ KB

# %%
happy2017_df.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716
# 4    0.245483                       0.382612           2.430182

# %%
happy2017_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 14.7+ KB

# %%
happy2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
happy2018_df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# 3                      0.138
# 4                      0.357

# %%
happy2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
happy2019_df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %% [markdown]
# ## Data Cleaning For World Happiness Data
#
# - Renaming columns (lowercase, remove spaces and replace with underscores, remove any other puncuntation)
# - Removing countries that do not appear across all years
# - Removing rows that have NaN values
# - Combine all years into master dataframe (combine this with Gini index afterwards)

# %% [markdown]
# ## Cleaning columns for happy2015_df

# %%
#drop columns not in other dataframes
happy2015_df.drop(columns=['Region','Standard Error', 'Dystopia Residual'], inplace=True)

#making columns headings lowercase
happy2015_df.columns = happy2015_df.columns.str.lower()

#change column names to use underscore instead of spaces
columns = happy2015_df.columns

corrected_columns = []
for col in columns:
    col = col.replace('(','').replace(')','').replace(' ','_')
    corrected_columns.append(col)
    

#changing names of certain columns to be consisent with the rest of the dataframes
corrected_columns[3] = 'gdp_per_capita'
corrected_columns[4] = 'family_social_support'
    
happy2015_df.columns = corrected_columns

happy2015_df.columns
# Out:
# Index(['country', 'happiness_rank', 'happiness_score', 'gdp_per_capita',
#        'family_social_support', 'health_life_expectancy', 'freedom',
#        'trust_government_corruption', 'generosity'],
#       dtype='object')

# %%
#adding a year column
happy2015_df.insert(loc=1, column='year', value=2015)
happy2015_df['year'] = happy2015_df['year'].astype(int)
happy2015_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      158 non-null    object
#  1   year                         158 non-null    int32
#  2   happiness_rank               158 non-null    int64
#  3   happiness_score              158 non-null    float64
#  4   gdp_per_capita               158 non-null    float64
#  5   family_social_support        158 non-null    float64
#  6   health_life_expectancy       158 non-null    float64
#  7   freedom                      158 non-null    float64
#  8   trust_government_corruption  158 non-null    float64
#  9   generosity                   158 non-null    float64
# dtypes: float64(7), int32(1), int64(1), object(1)
# memory usage: 11.9+ KB

# %% [markdown]
# ## Cleaning columns for happy2016_df

# %%
#drop columns not in other dataframes
happy2016_df.drop(columns=['Region','Lower Confidence Interval','Upper Confidence Interval', 'Dystopia Residual'], inplace=True)

#making columns headings lowercase
happy2016_df.columns = happy2016_df.columns.str.lower()

#change column names to use underscore instead of spaces
columns = happy2016_df.columns

corrected_columns = []
for col in columns:
    col = col.replace('(','').replace(')','').replace(' ','_')
    corrected_columns.append(col)
    

#changing names of certain columns to be consisent with the rest of the dataframes
corrected_columns[3] = 'gdp_per_capita'
corrected_columns[4] = 'family_social_support'
    
happy2016_df.columns = corrected_columns

happy2016_df.columns
# Out:
# Index(['country', 'happiness_rank', 'happiness_score', 'gdp_per_capita',
#        'family_social_support', 'health_life_expectancy', 'freedom',
#        'trust_government_corruption', 'generosity'],
#       dtype='object')

# %%
#adding a year column
happy2016_df.insert(loc=1, column='year', value=2016)
happy2016_df['year'] = happy2016_df['year'].astype(int)
happy2016_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      157 non-null    object
#  1   year                         157 non-null    int32
#  2   happiness_rank               157 non-null    int64
#  3   happiness_score              157 non-null    float64
#  4   gdp_per_capita               157 non-null    float64
#  5   family_social_support        157 non-null    float64
#  6   health_life_expectancy       157 non-null    float64
#  7   freedom                      157 non-null    float64
#  8   trust_government_corruption  157 non-null    float64
#  9   generosity                   157 non-null    float64
# dtypes: float64(7), int32(1), int64(1), object(1)
# memory usage: 11.8+ KB

# %% [markdown]
# ## Cleaning columns for happy2017_df

# %%
#drop columns not in other dataframes
happy2017_df.drop(columns=['Whisker.high','Whisker.low', 'Dystopia.Residual'], inplace=True)

#making columns headings lowercase
happy2017_df.columns = happy2017_df.columns.str.lower()

#change column names to use underscore instead of spaces
columns = happy2017_df.columns

corrected_columns = []
for col in columns:
    col = col.replace('..','.').replace('.','_')
    corrected_columns.append(col)
    

#changing names of certain columns to be consisent with the rest of the dataframes
corrected_columns[3] = 'gdp_per_capita'
corrected_columns[4] = 'family_social_support'
corrected_columns[5] = 'health_life_expectancy'
corrected_columns[8] = 'trust_government_corruption'
    
happy2017_df.columns = corrected_columns

happy2017_df.columns
# Out:
# Index(['country', 'happiness_rank', 'happiness_score', 'gdp_per_capita',
#        'family_social_support', 'health_life_expectancy', 'freedom',
#        'generosity', 'trust_government_corruption'],
#       dtype='object')

# %%
#adding a year column
happy2017_df.insert(loc=1, column='year', value=2017)
happy2017_df['year'] = happy2017_df['year'].astype(int)
happy2017_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      155 non-null    object
#  1   year                         155 non-null    int32
#  2   happiness_rank               155 non-null    int64
#  3   happiness_score              155 non-null    float64
#  4   gdp_per_capita               155 non-null    float64
#  5   family_social_support        155 non-null    float64
#  6   health_life_expectancy       155 non-null    float64
#  7   freedom                      155 non-null    float64
#  8   generosity                   155 non-null    float64
#  9   trust_government_corruption  155 non-null    float64
# dtypes: float64(7), int32(1), int64(1), object(1)
# memory usage: 11.6+ KB

# %% [markdown]
# ## Cleaning columns for happy2018_df

# %%
#making columns headings lowercase
happy2018_df.columns = happy2018_df.columns.str.lower()

#change column names to use underscore instead of spaces
columns = happy2018_df.columns

corrected_columns = []
for col in columns:
    col = col.replace(' ','_')
    corrected_columns.append(col)
    

#changing names of certain columns to be consisent with the rest of the dataframes
corrected_columns[0] = 'happiness_rank'
corrected_columns[1] = 'country'
corrected_columns[2] = 'happiness_score'
corrected_columns[4] = 'family_social_support'
corrected_columns[5] = 'health_life_expectancy'
corrected_columns[6] = 'freedom'
corrected_columns[8] = 'trust_government_corruption'
    
happy2018_df.columns = corrected_columns

happy2018_df.columns
# Out:
# Index(['happiness_rank', 'country', 'happiness_score', 'gdp_per_capita',
#        'family_social_support', 'health_life_expectancy', 'freedom',
#        'generosity', 'trust_government_corruption'],
#       dtype='object')

# %%
#adding a year column
happy2018_df.insert(loc=1, column='year', value=2018)
happy2018_df['year'] = happy2018_df['year'].astype(int)
happy2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   happiness_rank               156 non-null    int64
#  1   year                         156 non-null    int32
#  2   country                      156 non-null    object
#  3   happiness_score              156 non-null    float64
#  4   gdp_per_capita               156 non-null    float64
#  5   family_social_support        156 non-null    float64
#  6   health_life_expectancy       156 non-null    float64
#  7   freedom                      156 non-null    float64
#  8   generosity                   156 non-null    float64
#  9   trust_government_corruption  155 non-null    float64
# dtypes: float64(7), int32(1), int64(1), object(1)
# memory usage: 11.7+ KB

# %% [markdown]
# ## Cleaning columns for happy2019_df

# %%
#making columns headings lowercase
happy2019_df.columns = happy2019_df.columns.str.lower()

#change column names to use underscore instead of spaces
columns = happy2019_df.columns

corrected_columns = []
for col in columns:
    col = col.replace(' ','_')
    corrected_columns.append(col)
    

#changing names of certain columns to be consisent with the rest of the dataframes
corrected_columns[0] = 'happiness_rank'
corrected_columns[1] = 'country'
corrected_columns[2] = 'happiness_score'
corrected_columns[4] = 'family_social_support'
corrected_columns[5] = 'health_life_expectancy'
corrected_columns[6] = 'freedom'
corrected_columns[8] = 'trust_government_corruption'
    
happy2019_df.columns = corrected_columns

happy2019_df.columns
# Out:
# Index(['happiness_rank', 'country', 'happiness_score', 'gdp_per_capita',
#        'family_social_support', 'health_life_expectancy', 'freedom',
#        'generosity', 'trust_government_corruption'],
#       dtype='object')

# %%
#adding a year column
happy2019_df.insert(loc=1, column='year', value=2019)
happy2019_df['year'] = happy2019_df['year'].astype(int)
happy2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   happiness_rank               156 non-null    int64
#  1   year                         156 non-null    int32
#  2   country                      156 non-null    object
#  3   happiness_score              156 non-null    float64
#  4   gdp_per_capita               156 non-null    float64
#  5   family_social_support        156 non-null    float64
#  6   health_life_expectancy       156 non-null    float64
#  7   freedom                      156 non-null    float64
#  8   generosity                   156 non-null    float64
#  9   trust_government_corruption  156 non-null    float64
# dtypes: float64(7), int32(1), int64(1), object(1)
# memory usage: 11.7+ KB

# %% [markdown]
# ## Cleaning rows
#
#  - All dataframes now have the same amount of columns and the names are consisent.
#  - Now the countries need to be consistent across all data frames.
#  - NaN values need to be dropped. (Only applies to happy2018_df)

# %% [markdown]
# ## Cleaning rows from happy2015_df and happy2017_df

# %%
# Turning country columns to sets to make it easier to determine differences between them
countries_2017 = set(happy2017_df['country'].sort_values())
countries_2015 = set(happy2015_df['country'].sort_values())

#comparing each set to the countries_2017 set since it contains the least amount of items
non_matches = countries_2017 ^ countries_2015

#differences between the dataframes
non_matches
# Out:
# {'Belize',
#  'Comoros',
#  'Djibouti',
#  'Hong Kong',
#  'Hong Kong S.A.R., China',
#  'Laos',
#  'Namibia',
#  'Oman',
#  'Somalia',
#  'Somaliland region',
#  'South Sudan',
#  'Suriname',
#  'Swaziland',
#  'Taiwan',
#  'Taiwan Province of China'}

# %%
#changing the values of the countries that are the same, but have a different spelling (Checking for false positives)
happy2017_df.loc[happy2017_df['country'].str.contains('Hong')]

#using .at to select value
happy2017_df.at[70, "country"] = 'Hong Kong'
print(happy2017_df.at[70, "country"])
# Out:
# Hong Kong

# %%
happy2017_df.loc[happy2017_df['country'].str.contains('Tai')]

#using .at to select value
happy2017_df.at[32, "country"] = 'Taiwan'
print(happy2017_df.at[32, "country"] )
# Out:
# Taiwan

# %%
#running the set operation a second time
countries_2017 = set(happy2017_df['country'].sort_values())
countries_2015 = set(happy2015_df['country'].sort_values())

non_matches = countries_2017 ^ countries_2015

#remoing countries in no_matches from the dataframes
non_matches = list(non_matches)
print(non_matches)

happy2017_df = happy2017_df.loc[~happy2017_df['country'].isin(non_matches)]
happy2015_df = happy2015_df.loc[~happy2015_df['country'].isin(non_matches)]

#Also going to remove these from the rest of the dataframes
happy2016_df = happy2016_df.loc[~happy2016_df['country'].isin(non_matches)]
happy2018_df = happy2018_df.loc[~happy2018_df['country'].isin(non_matches)]
happy2019_df = happy2019_df.loc[~happy2019_df['country'].isin(non_matches)]
# Out:
# ['Somalia', 'Oman', 'Djibouti', 'Laos', 'Namibia', 'South Sudan', 'Swaziland', 'Belize', 'Somaliland region', 'Comoros', 'Suriname']

# %%
#running set operation one last time to make sure that rows are the same
countries_2017 = set(happy2017_df['country'].sort_values())
countries_2015 = set(happy2015_df['country'].sort_values())

non_matches = countries_2017 ^ countries_2015
print(non_matches,len(happy2015_df), len(happy2017_df))
# Out:
# set() 151 151

# %% [markdown]
# ## Cleaning rows from happy2016_df

# %%
# Turning country columns to sets to make it easier to determine differences between them
countries_2016 = set(happy2016_df['country'].sort_values())

#comparing each set to the countries_2017 set since it contains the least amount of items
non_matches = countries_2017 ^ countries_2016

#differences between the dataframes
non_matches
# Out:
# {'Central African Republic',
#  'Lesotho',
#  'Mozambique',
#  'Puerto Rico',
#  'Somaliland Region'}

# %%
#remoing countries in no_matches from the dataframes (checked for false positives, but did not find any)
non_matches = list(non_matches)
print(non_matches)

happy2017_df = happy2017_df.loc[~happy2017_df['country'].isin(non_matches)]
happy2015_df = happy2015_df.loc[~happy2015_df['country'].isin(non_matches)]

#Also going to remove these from the rest of the dataframes
happy2016_df = happy2016_df.loc[~happy2016_df['country'].isin(non_matches)]
happy2018_df = happy2018_df.loc[~happy2018_df['country'].isin(non_matches)]
happy2019_df = happy2019_df.loc[~happy2019_df['country'].isin(non_matches)]
# Out:
# ['Lesotho', 'Central African Republic', 'Mozambique', 'Somaliland Region', 'Puerto Rico']

# %%
#running set operation one last time to make sure that rows are the same
countries_2017 = set(happy2017_df['country'].sort_values())
countries_2016 = set(happy2016_df['country'].sort_values())

non_matches = countries_2017 ^ countries_2016
print(non_matches,len(happy2016_df), len(happy2017_df))
# Out:
# set() 148 148

# %% [markdown]
# ## Cleaning rows from happy2018_df

# %%
#Dropping row with NaN
happy2018_df.dropna(inplace=True)
happy2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   happiness_rank               147 non-null    int64
#  1   year                         147 non-null    int32
#  2   country                      147 non-null    object
#  3   happiness_score              147 non-null    float64
#  4   gdp_per_capita               147 non-null    float64
#  5   family_social_support        147 non-null    float64
#  6   health_life_expectancy       147 non-null    float64
#  7   freedom                      147 non-null    float64
#  8   generosity                   147 non-null    float64
#  9   trust_government_corruption  147 non-null    float64
# dtypes: float64(7), int32(1), int64(1), object(1)
# memory usage: 12.1+ KB

# %%
#Turning country columns to sets to make it easier to determine differences between them
countries_2018 = set(happy2018_df['country'].sort_values())

#comparing each set to the countries_2017 set since it contains the least amount of items
non_matches = countries_2017 ^ countries_2018

#differences between the dataframes
non_matches
# Out:
# {'North Cyprus',
#  'Northern Cyprus',
#  'Trinidad & Tobago',
#  'Trinidad and Tobago',
#  'United Arab Emirates'}

# %%
#changing the values of the countries that are the same, but have a different spelling (Checking for false positives)
happy2017_df.loc[happy2017_df['country'].str.contains('Cypru')]

#using .at to select value
happy2017_df.at[60, "country"] = 'Northern Cyprus'
print(happy2017_df.at[60, "country"])
# Out:
# Northern Cyprus

# %%
#changing the values of the countries that are the same, but have a different spelling (Checking for false positives)
happy2018_df.loc[happy2018_df['country'].str.contains('Toba')]

#using .at to select value
happy2018_df.at[37, "country"] = 'Trinidad and Tobago'
print(happy2017_df.at[37, "country"])
# Out:
# Trinidad and Tobago

# %%
#remoing countries in no_matches from the dataframes
non_matches = list(non_matches)
print(non_matches)

happy2017_df = happy2017_df.loc[~happy2017_df['country'].isin(non_matches)]
happy2015_df = happy2015_df.loc[~happy2015_df['country'].isin(non_matches)]

#Also going to remove these from the rest of the dataframes
happy2016_df = happy2016_df.loc[~happy2016_df['country'].isin(non_matches)]
happy2018_df = happy2018_df.loc[~happy2018_df['country'].isin(non_matches)]
happy2019_df = happy2019_df.loc[~happy2019_df['country'].isin(non_matches)]
# Out:
# ['North Cyprus', 'Trinidad & Tobago', 'United Arab Emirates', 'Trinidad and Tobago', 'Northern Cyprus']

# %%
#running set operation one last time to make sure that rows are the same
countries_2017 = set(happy2017_df['country'].sort_values())
countries_2018 = set(happy2018_df['country'].sort_values())

non_matches = countries_2017 ^ countries_2018
print(non_matches,len(happy2018_df), len(happy2017_df))
# Out:
# set() 145 145

# %% [markdown]
# ## Cleaning rows from happy2019_df

# %%
#Turning country columns to sets to make it easier to determine differences between them
countries_2019 = set(happy2019_df['country'].sort_values())

#comparing each set to the countries_2017 set since it contains the least amount of items
non_matches = countries_2017 ^ countries_2019

#differences between the dataframes
non_matches
# Out:
# {'Angola', 'Gambia', 'Macedonia', 'North Macedonia', 'Sudan'}

# %%
#changing the values of the countries that are the same, but have a different spelling (Checking for false positives)
happy2019_df.loc[happy2019_df['country'].str.contains('Toba')]

#using .at to select value
happy2019_df.at[38, "country"] = 'Trinidad and Tobago'
print(happy2019_df.at[38, "country"])
# Out:
# Trinidad and Tobago

# %%
#running the set operation a second time
countries_2017 = set(happy2017_df['country'].sort_values())
countries_2019 = set(happy2019_df['country'].sort_values())

non_matches = countries_2017 ^ countries_2019

#remoing countries in no_matches from the dataframes
non_matches = list(non_matches)
print(non_matches)

happy2017_df = happy2017_df.loc[~happy2017_df['country'].isin(non_matches)]
happy2015_df = happy2015_df.loc[~happy2015_df['country'].isin(non_matches)]

#Also going to remove these from the rest of the dataframes
happy2016_df = happy2016_df.loc[~happy2016_df['country'].isin(non_matches)]
happy2018_df = happy2018_df.loc[~happy2018_df['country'].isin(non_matches)]
happy2019_df = happy2019_df.loc[~happy2019_df['country'].isin(non_matches)]
# Out:
# ['Angola', 'Gambia', 'Macedonia', 'Trinidad and Tobago', 'North Macedonia', 'Sudan']

# %%
#running set operation one last time to make sure that rows are the same
countries_2017 = set(happy2017_df['country'].sort_values())
countries_2019 = set(happy2019_df['country'].sort_values())

non_matches = countries_2017 ^ countries_2019
print(non_matches,len(happy2019_df), len(happy2017_df))
# Out:
# set() 142 142

# %% [markdown]
# ## Final row cleanup

# %%
#Going through to compare sets again
countries_2015 = set(happy2015_df['country'].sort_values())
countries_2017 = set(happy2017_df['country'].sort_values())

non_matches = countries_2017 ^ countries_2015
print(non_matches)
# Out:
# set()

# %%
#Going through to compare sets again
countries_2016 = set(happy2016_df['country'].sort_values())
non_matches = countries_2017 ^ countries_2016
print(non_matches)
# Out:
# set()

# %%
countries_2016 = set(happy2016_df['country'].sort_values())
non_matches = countries_2017 ^ countries_2016
print(non_matches)
# Out:
# set()

# %%
#Going through to compare sets again
countries_2018 = set(happy2018_df['country'].sort_values())
non_matches = countries_2017 ^ countries_2018
print(non_matches)
# Out:
# set()

# %%
#Going through to compare sets again
countries_2019 = set(happy2019_df['country'].sort_values())
non_matches = countries_2017 ^ countries_2019
print(non_matches)
# Out:
# set()

# %% [markdown]
# ## Combining dataframes into master dataframe

# %%
#Combining dataframes into one
happy_master_df = pd.concat([happy2015_df, happy2016_df, happy2017_df, happy2018_df, happy2019_df], ignore_index=True)

happy_master_df.head()
# Out:
#        country    year  happiness_rank  happiness_score  gdp_per_capita  \
# 0  Switzerland  2015.0             1.0            7.587         1.39651
# 1      Iceland  2015.0             2.0            7.561         1.30232
# 2      Denmark  2015.0             3.0            7.527         1.32548
# 3       Norway  2015.0             4.0            7.522         1.45900
# 4       Canada  2015.0             5.0            7.427         1.32629
#
#    family_social_support  health_life_expectancy  freedom  \
# 0                1.34951                 0.94143  0.66557
# 1                1.40223                 0.94784  0.62877
# 2                1.36058                 0.87464  0.64938
# 3                1.33095                 0.88521  0.66973
# 4                1.32261                 0.90563  0.63297
#
#    trust_government_corruption  generosity
# 0                      0.41978     0.29678
# 1                      0.14145     0.43630
# 2                      0.48357     0.34139
# 3                      0.36503     0.34699
# 4                      0.32957     0.45811

# %%
happy_master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 710 entries, 0 to 709
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      710 non-null    object
#  1   year                         710 non-null    float64
#  2   happiness_rank               710 non-null    float64
#  3   happiness_score              710 non-null    float64
#  4   gdp_per_capita               710 non-null    float64
#  5   family_social_support        710 non-null    float64
#  6   health_life_expectancy       710 non-null    float64
#  7   freedom                      710 non-null    float64
#  8   trust_government_corruption  710 non-null    float64
#  9   generosity                   710 non-null    float64
# dtypes: float64(9), object(1)
# memory usage: 55.6+ KB

# %%
#correcting data type for 
happy_master_df['year'] = happy_master_df['year'].astype(int)

# %% [markdown]
# ## Data Cleaning For Ginni Index and Other World Development Indicators For Income
#
# - Renaming columns (lowercase, remove spaces and replace with underscores, remove any other puncuntation)
# - Removing countries that do not appear across all years
# - Removing rows with NaN values
# - Transform each unique value in Series Name to its own column
# - Transform each year column into its own row
# - Combine the dataframe with master dataframe for world happiness

# %%
#loading the data
gini_income_raw = pd.read_csv('income_data/world_bank_income_data.csv')

#Saving copy of gini_index_raw to preserve data
gini_income = gini_income_raw.copy()

gini_income.head()
# Out:
#   Series Name  Series Code    Country Name Country Code 1990 [YR1990]  \
# 0  Gini index  SI.POV.GINI     Afghanistan          AFG            ..
# 1  Gini index  SI.POV.GINI         Albania          ALB            ..
# 2  Gini index  SI.POV.GINI         Algeria          DZA            ..
# 3  Gini index  SI.POV.GINI  American Samoa          ASM            ..
# 4  Gini index  SI.POV.GINI         Andorra          AND            ..
#
#   2000 [YR2000] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]  \
# 0            ..            ..            ..            ..            ..
# 1            ..            29            ..          34.6          32.8
# 2            ..            ..            ..            ..            ..
# 3            ..            ..            ..            ..            ..
# 4            ..            ..            ..            ..            ..
#
#   2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019] 2020 [YR2020]  \
# 0            ..            ..            ..            ..            ..
# 1          33.7          33.1          30.1          30.8            ..
# 2            ..            ..            ..            ..            ..
# 3            ..            ..            ..            ..            ..
# 4            ..            ..            ..            ..            ..
#
#   2021 [YR2021]
# 0            ..
# 1            ..
# 2            ..
# 3            ..
# 4            ..

# %%
gini_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3197 entries, 0 to 3196
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series Name    3194 non-null   object
#  1   Series Code    3192 non-null   object
#  2   Country Name   3192 non-null   object
#  3   Country Code   3192 non-null   object
#  4   1990 [YR1990]  3192 non-null   object
#  5   2000 [YR2000]  3192 non-null   object
#  6   2012 [YR2012]  3192 non-null   object
#  7   2013 [YR2013]  3192 non-null   object
#  8   2014 [YR2014]  3192 non-null   object
#  9   2015 [YR2015]  3192 non-null   object
#  10  2016 [YR2016]  3192 non-null   object
#  11  2017 [YR2017]  3192 non-null   object
#  12  2018 [YR2018]  3192 non-null   object
#  13  2019 [YR2019]  3192 non-null   object
#  14  2020 [YR2020]  3192 non-null   object
#  15  2021 [YR2021]  3192 non-null   object
# dtypes: object(16)
# memory usage: 399.8+ KB

# %% [markdown]
# ## Cleaning up column names

# %%
#removing everything before 2015
gini_income.drop(gini_income.iloc[:, 4:9], inplace=True, axis=1)

#removing everything after 2019
gini_income.drop(gini_income.iloc[:, 9:], inplace=True, axis=1)

gini_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3197 entries, 0 to 3196
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series Name    3194 non-null   object
#  1   Series Code    3192 non-null   object
#  2   Country Name   3192 non-null   object
#  3   Country Code   3192 non-null   object
#  4   2015 [YR2015]  3192 non-null   object
#  5   2016 [YR2016]  3192 non-null   object
#  6   2017 [YR2017]  3192 non-null   object
#  7   2018 [YR2018]  3192 non-null   object
#  8   2019 [YR2019]  3192 non-null   object
# dtypes: object(9)
# memory usage: 224.9+ KB

# %%
#making columns headings lowercase
gini_income.columns = gini_income.columns.str.lower()

#change column names to use underscore instead of spaces
columns = gini_income.columns

corrected_columns = []
for col in columns:
    col = col.replace('[yr201','').replace(' ','_')
    corrected_columns.append(col)
    
    
#changing names of certain columns to be consisent with the rest of the dataframes
corrected_columns[0] = 'income_indicator'
corrected_columns[1] = 'income_indicator_code'
corrected_columns[2] = 'country'
corrected_columns[4] = '2015'
corrected_columns[5] = '2016'
corrected_columns[6] = '2017'
corrected_columns[7] = '2018'
corrected_columns[8] = '2019' 

    
gini_income.columns = corrected_columns

gini_income.columns
# Out:
# Index(['income_indicator', 'income_indicator_code', 'country', 'country_code',
#        '2015', '2016', '2017', '2018', '2019'],
#       dtype='object')

# %% [markdown]
# ## Cleaning rows

# %%
gini_income.head()
# Out:
#   income_indicator income_indicator_code         country country_code  2015  \
# 0       Gini index           SI.POV.GINI     Afghanistan          AFG    ..
# 1       Gini index           SI.POV.GINI         Albania          ALB  32.8
# 2       Gini index           SI.POV.GINI         Algeria          DZA    ..
# 3       Gini index           SI.POV.GINI  American Samoa          ASM    ..
# 4       Gini index           SI.POV.GINI         Andorra          AND    ..
#
#    2016  2017  2018  2019
# 0    ..    ..    ..    ..
# 1  33.7  33.1  30.1  30.8
# 2    ..    ..    ..    ..
# 3    ..    ..    ..    ..
# 4    ..    ..    ..    ..

# %%
#Replacing '..' value with blank value
gini_income['2015'] = gini_income['2015'].str.replace('..', '', regex=False)
gini_income['2015'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3197 entries, 0 to 3196
# Series name: 2015
# Non-Null Count  Dtype
# --------------  -----
# 3192 non-null   object
# dtypes: object(1)
# memory usage: 25.1+ KB

# %%
#Replacing '..' value with blank value
gini_income['2016'] = gini_income['2016'].str.replace('..', '', regex=False)
gini_income['2016'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3197 entries, 0 to 3196
# Series name: 2016
# Non-Null Count  Dtype
# --------------  -----
# 3192 non-null   object
# dtypes: object(1)
# memory usage: 25.1+ KB

# %%
#Replacing '..' value with blank value
gini_income['2017'] = gini_income['2017'].str.replace('..', '', regex=False)
gini_income['2017'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3197 entries, 0 to 3196
# Series name: 2017
# Non-Null Count  Dtype
# --------------  -----
# 3192 non-null   object
# dtypes: object(1)
# memory usage: 25.1+ KB

# %%
#Replacing '..' value with blank value
gini_income['2018'] = gini_income['2018'].str.replace('..', '', regex=False)
gini_income['2018'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3197 entries, 0 to 3196
# Series name: 2018
# Non-Null Count  Dtype
# --------------  -----
# 3192 non-null   object
# dtypes: object(1)
# memory usage: 25.1+ KB

# %%
#Replacing '..' value with blank value
gini_income['2019'] = gini_income['2019'].str.replace('..', '', regex=False)
gini_income['2019'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3197 entries, 0 to 3196
# Series name: 2019
# Non-Null Count  Dtype
# --------------  -----
# 3192 non-null   object
# dtypes: object(1)
# memory usage: 25.1+ KB

# %%
#using mask to replace blank values with NaN
gini_income = gini_income.mask(gini_income == '')

gini_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3197 entries, 0 to 3196
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   income_indicator       3194 non-null   object
#  1   income_indicator_code  3192 non-null   object
#  2   country                3192 non-null   object
#  3   country_code           3192 non-null   object
#  4   2015                   1510 non-null   object
#  5   2016                   1447 non-null   object
#  6   2017                   1400 non-null   object
#  7   2018                   1472 non-null   object
#  8   2019                   1238 non-null   object
# dtypes: object(9)
# memory usage: 224.9+ KB

# %%
#dropping all NaN values
gini_income.dropna(inplace=True)
gini_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1167 entries, 1 to 3133
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   income_indicator       1167 non-null   object
#  1   income_indicator_code  1167 non-null   object
#  2   country                1167 non-null   object
#  3   country_code           1167 non-null   object
#  4   2015                   1167 non-null   object
#  5   2016                   1167 non-null   object
#  6   2017                   1167 non-null   object
#  7   2018                   1167 non-null   object
#  8   2019                   1167 non-null   object
# dtypes: object(9)
# memory usage: 91.2+ KB

# %%
#Correcting data type for 2015,2016, 2017, 2018, and 2019 columns
gini_income['2015'] = gini_income['2015'].astype(float)
gini_income['2016'] = gini_income['2016'].astype(float)
gini_income['2017'] = gini_income['2017'].astype(float)
gini_income['2018'] = gini_income['2018'].astype(float)
gini_income['2019'] = gini_income['2019'].astype(float)

gini_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1167 entries, 1 to 3133
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   income_indicator       1167 non-null   object
#  1   income_indicator_code  1167 non-null   object
#  2   country                1167 non-null   object
#  3   country_code           1167 non-null   object
#  4   2015                   1167 non-null   float64
#  5   2016                   1167 non-null   float64
#  6   2017                   1167 non-null   float64
#  7   2018                   1167 non-null   float64
#  8   2019                   1167 non-null   float64
# dtypes: float64(5), object(4)
# memory usage: 91.2+ KB

# %%
gini_income.head()
# Out:
#    income_indicator income_indicator_code  country country_code  2015  2016  \
# 1        Gini index           SI.POV.GINI  Albania          ALB  32.8  33.7
# 8        Gini index           SI.POV.GINI  Armenia          ARM  32.4  32.5
# 11       Gini index           SI.POV.GINI  Austria          AUT  30.5  30.8
# 17       Gini index           SI.POV.GINI  Belarus          BLR  25.6  25.3
# 18       Gini index           SI.POV.GINI  Belgium          BEL  27.7  27.6
#
#     2017  2018  2019
# 1   33.1  30.1  30.8
# 8   33.6  34.4  29.9
# 11  29.7  30.8  30.2
# 17  25.4  25.2  25.3
# 18  27.4  27.2  27.2

# %%
#matching countries to the ones in the Happy_master_df

gini_countries = set(gini_income['country'].values)
happy_countries = set(happy_master_df['country'].values)

non_matches = gini_countries ^ happy_countries

non_matches
# Out:
# {'Africa Eastern and Southern',
#  'Africa Western and Central',
#  'Angola',
#  'Arab World',
#  'Bahamas, The',
#  'Barbados',
#  'Belize',
#  'Brunei Darussalam',
#  'Cabo Verde',
#  'Caribbean small states',
#  'Central African Republic',
#  'Central Europe and the Baltics',
#  'Comoros',
#  'Congo (Brazzaville)',
#  'Congo (Kinshasa)',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  "Cote d'Ivoire",
#  'Djibouti',
#  'Dominica',
#  'Early-demographic dividend',
#  'East Asia & Pacific',
#  'East Asia & Pacific (IDA & IBRD countries)',
#  'East Asia & Pacific (excluding high income)',
#  'Egypt',
#  'Egypt, Arab Rep.',
#  'Equatorial Guinea',
#  'Eswatini',
#  'Euro area',
#  'Europe & Central Asia',
#  'Europe & Central Asia (IDA & IBRD countries)',
#  'Europe & Central Asia (excluding high income)',
#  'European Union',
#  'Fiji',
#  'Fragile and conflict affected situations',
#  'Gambia, The',
#  'Guinea-Bissau',
#  'Guyana',
#  'Heavily indebted poor countries (HIPC)',
#  'High income',
#  'Hong Kong',
#  'IBRD only',
#  'IDA & IBRD total',
#  'IDA blend',
#  'IDA only',
#  'IDA total',
#  'Iran',
#  'Iran, Islamic Rep.',
#  'Ivory Coast',
#  'Kiribati',
#  'Korea, Rep.',
#  'Kosovo',
#  'Kyrgyz Republic',
#  'Kyrgyzstan',
#  'Lao PDR',
#  'Late-demographic dividend',
#  'Latin America & Caribbean',
#  'Latin America & Caribbean (excluding high income)',
#  'Latin America & the Caribbean (IDA & IBRD countries)',
#  'Least developed countries: UN classification',
#  'Lesotho',
#  'Low & middle income',
#  'Low income',
#  'Lower middle income',
#  'Maldives',
#  'Micronesia, Fed. Sts.',
#  'Middle East & North Africa',
#  'Middle East & North Africa (IDA & IBRD countries)',
#  'Middle East & North Africa (excluding high income)',
#  'Middle income',
#  'Mozambique',
#  'Namibia',
#  'North America',
#  'North Macedonia',
#  'OECD members',
#  'Oman',
#  'Other small states',
#  'Pacific island small states',
#  'Palestinian Territories',
#  'Papua New Guinea',
#  'Post-demographic dividend',
#  'Pre-demographic dividend',
#  'Russia',
#  'Russian Federation',
#  'Samoa',
#  'Sao Tome and Principe',
#  'Seychelles',
#  'Slovak Republic',
#  'Slovakia',
#  'Small states',
#  'Solomon Islands',
#  'Somalia',
#  'South Asia',
#  'South Asia (IDA & IBRD)',
#  'South Korea',
#  'St. Lucia',
#  'St. Vincent and the Grenadines',
#  'Sub-Saharan Africa',
#  'Sub-Saharan Africa (IDA & IBRD countries)',
#  'Sub-Saharan Africa (excluding high income)',
#  'Sudan',
#  'Suriname',
#  'Syria',
#  'Taiwan',
#  'Timor-Leste',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Turkey',
#  'Turkiye',
#  'Turkmenistan',
#  'Turks and Caicos Islands',
#  'United Arab Emirates',
#  'United Kingdom',
#  'Upper middle income',
#  'Vanuatu',
#  'Venezuela',
#  'World',
#  'Yemen'}

# %%
#changing the values of the countries that are the same, but have a different spelling (Checking for false positives)
gini_income.loc[gini_income['country'].str.contains('Russ')]


#changing country value
gini_income['country'] = gini_income['country'].str.replace('Russian Federation', 'Russia', regex=False)
gini_income.loc[gini_income['country'].str.contains('Russ')]
# Out:
#                                        income_indicator income_indicator_code  \
# 161                                          Gini index           SI.POV.GINI
# 427      Adjusted net national income (annual % growth)     NY.ADJ.NNTY.KD.ZG
# 693   Adjusted net national income per capita (annua...  NY.ADJ.NNTY.PC.KD.ZG
# 959          Adjusted net national income (current US$)        NY.ADJ.NNTY.CD
# 1225  Adjusted net national income per capita (const...     NY.ADJ.NNTY.PC.KD
# 1491                    Income share held by fourth 20%        SI.DST.04TH.20
# 1757                   Income share held by highest 10%        SI.DST.10TH.10
# 2023                   Income share held by highest 20%        SI.DST.05TH.20
# 2289                    Income share held by lowest 10%        SI.DST.FRST.10
# 2555                    Income share held by lowest 20%        SI.DST.FRST.20
# 2821                    Income share held by second 20%        SI.DST.02ND.20
# 3087                     Income share held by third 20%        SI.DST.03RD.20
#
#      country country_code          2015          2016          2017  \
# 161   Russia          RUS  3.770000e+01  3.680000e+01  3.720000e+01
# 427   Russia          RUS -5.329908e+00 -4.277363e+00  3.160426e+00
# 693   Russia          RUS -5.495378e+00 -4.449222e+00  3.011909e+00
# 959   Russia          RUS  1.086804e+12  1.010782e+12  1.233100e+12
# 1225  Russia          RUS  7.423222e+03  7.092694e+03  7.308489e+03
# 1491  Russia          RUS  2.150000e+01  2.190000e+01  2.170000e+01
# 1757  Russia          RUS  2.970000e+01  2.860000e+01  2.920000e+01
# 2023  Russia          RUS  4.530000e+01  4.440000e+01  4.480000e+01
# 2289  Russia          RUS  2.800000e+00  2.800000e+00  2.900000e+00
# 2555  Russia          RUS  6.900000e+00  7.000000e+00  7.100000e+00
# 2821  Russia          RUS  1.110000e+01  1.120000e+01  1.120000e+01
# 3087  Russia          RUS  1.520000e+01  1.550000e+01  1.530000e+01
#
#               2018          2019
# 161   3.750000e+01  3.770000e+01
# 427   5.798343e+00 -1.349740e+00
# 693   5.803796e+00 -9.681295e-01
# 959   1.277141e+12  1.280765e+12
# 1225  7.732883e+03  7.631936e+03
# 1491  2.140000e+01  2.140000e+01
# 1757  2.990000e+01  3.020000e+01
# 2023  4.510000e+01  4.530000e+01
# 2289  2.900000e+00  2.900000e+00
# 2555  7.100000e+00  7.100000e+00
# 2821  1.120000e+01  1.110000e+01
# 3087  1.520000e+01  1.520000e+01

# %%
#changing the values of the countries that are the same, but have a different spelling (Checking for false positives)
gini_income.loc[gini_income['country'].str.contains('Iran')]


#change country value
gini_income['country'] = gini_income['country'].str.replace('Iran, Islamic Rep.', 'Iran', regex=False)
gini_income.loc[gini_income['country'].str.contains('Iran')]
# Out:
#                                 income_indicator income_indicator_code  \
# 91                                    Gini index           SI.POV.GINI
# 889   Adjusted net national income (current US$)        NY.ADJ.NNTY.CD
# 1421             Income share held by fourth 20%        SI.DST.04TH.20
# 1687            Income share held by highest 10%        SI.DST.10TH.10
# 1953            Income share held by highest 20%        SI.DST.05TH.20
# 2219             Income share held by lowest 10%        SI.DST.FRST.10
# 2485             Income share held by lowest 20%        SI.DST.FRST.20
# 2751             Income share held by second 20%        SI.DST.02ND.20
# 3017              Income share held by third 20%        SI.DST.03RD.20
#
#      country country_code          2015          2016          2017  \
# 91      Iran          IRN  3.950000e+01  4.000000e+01  4.080000e+01
# 889     Iran          IRN  3.064803e+11  3.381466e+11  3.517886e+11
# 1421    Iran          IRN  2.160000e+01  2.170000e+01  2.170000e+01
# 1687    Iran          IRN  3.060000e+01  3.090000e+01  3.130000e+01
# 1953    Iran          IRN  4.640000e+01  4.670000e+01  4.730000e+01
# 2219    Iran          IRN  2.400000e+00  2.400000e+00  2.300000e+00
# 2485    Iran          IRN  6.300000e+00  6.100000e+00  5.900000e+00
# 2751    Iran          IRN  1.070000e+01  1.050000e+01  1.030000e+01
# 3017    Iran          IRN  1.500000e+01  1.490000e+01  1.480000e+01
#
#               2018          2019
# 91    4.200000e+01  4.090000e+01
# 889   2.097013e+11  1.934630e+11
# 1421  2.130000e+01  2.160000e+01
# 1687  3.250000e+01  3.170000e+01
# 1953  4.850000e+01  4.750000e+01
# 2219  2.200000e+00  2.300000e+00
# 2485  5.800000e+00  6.000000e+00
# 2751  1.000000e+01  1.030000e+01
# 3017  1.430000e+01  1.470000e+01

# %%
#changing the values of the countries that are the same, but have a different spelling (Checking for false positives)
gini_income.loc[gini_income['country'].str.contains('Kyrgy')]


#change country value
gini_income['country'] = gini_income['country'].str.replace('Kyrgyz Republic', 'Kyrgyzstan', regex=False)
gini_income.loc[gini_income['country'].str.contains('Kyrgy')]
# Out:
#                                        income_indicator income_indicator_code  \
# 107                                          Gini index           SI.POV.GINI
# 373      Adjusted net national income (annual % growth)     NY.ADJ.NNTY.KD.ZG
# 639   Adjusted net national income per capita (annua...  NY.ADJ.NNTY.PC.KD.ZG
# 905          Adjusted net national income (current US$)        NY.ADJ.NNTY.CD
# 1171  Adjusted net national income per capita (const...     NY.ADJ.NNTY.PC.KD
# 1437                    Income share held by fourth 20%        SI.DST.04TH.20
# 1703                   Income share held by highest 10%        SI.DST.10TH.10
# 1969                   Income share held by highest 20%        SI.DST.05TH.20
# 2235                    Income share held by lowest 10%        SI.DST.FRST.10
# 2501                    Income share held by lowest 20%        SI.DST.FRST.20
# 2767                    Income share held by second 20%        SI.DST.02ND.20
# 3033                     Income share held by third 20%        SI.DST.03RD.20
#
#          country country_code          2015          2016          2017  \
# 107   Kyrgyzstan          KGZ  2.900000e+01  2.680000e+01  2.730000e+01
# 373   Kyrgyzstan          KGZ  1.900039e+00  1.350361e+01  4.605723e+00
# 639   Kyrgyzstan          KGZ -1.766559e-01  1.121468e+01  2.602448e+00
# 905   Kyrgyzstan          KGZ  5.056791e+09  5.386731e+09  5.946203e+09
# 1171  Kyrgyzstan          KGZ  8.488965e+02  9.440975e+02  9.686671e+02
# 1437  Kyrgyzstan          KGZ  2.150000e+01  2.180000e+01  2.190000e+01
# 1703  Kyrgyzstan          KGZ  2.480000e+01  2.290000e+01  2.330000e+01
# 1969  Kyrgyzstan          KGZ  3.880000e+01  3.720000e+01  3.740000e+01
# 2235  Kyrgyzstan          KGZ  4.100000e+00  4.400000e+00  4.300000e+00
# 2501  Kyrgyzstan          KGZ  9.500000e+00  1.000000e+01  9.900000e+00
# 2767  Kyrgyzstan          KGZ  1.340000e+01  1.390000e+01  1.370000e+01
# 3033  Kyrgyzstan          KGZ  1.680000e+01  1.710000e+01  1.710000e+01
#
#               2018          2019
# 107   2.770000e+01  2.970000e+01
# 373   1.179514e+01 -4.086925e+00
# 639   9.592054e+00 -6.068710e+00
# 905   6.768169e+09  6.423165e+09
# 1171  1.061582e+03  9.971578e+02
# 1437  2.180000e+01  2.120000e+01
# 1703  2.360000e+01  2.580000e+01
# 1969  3.780000e+01  3.950000e+01
# 2235  4.300000e+00  4.100000e+00
# 2501  9.900000e+00  9.600000e+00
# 2767  1.350000e+01  1.320000e+01
# 3033  1.700000e+01  1.650000e+01

# %%
#changing the values of the countries that are the same, but have a different spelling (Checking for false positives)
gini_income.loc[gini_income['country'].str.contains('Slova')]


#using change country value
gini_income['country'] = gini_income['country'].str.replace('Slovak Republic', 'Slovakia', regex=False)
gini_income.loc[gini_income['country'].str.contains('Slova')]
# Out:
#                                        income_indicator income_indicator_code  \
# 173                                          Gini index           SI.POV.GINI
# 439      Adjusted net national income (annual % growth)     NY.ADJ.NNTY.KD.ZG
# 705   Adjusted net national income per capita (annua...  NY.ADJ.NNTY.PC.KD.ZG
# 971          Adjusted net national income (current US$)        NY.ADJ.NNTY.CD
# 1237  Adjusted net national income per capita (const...     NY.ADJ.NNTY.PC.KD
# 1503                    Income share held by fourth 20%        SI.DST.04TH.20
# 1769                   Income share held by highest 10%        SI.DST.10TH.10
# 2035                   Income share held by highest 20%        SI.DST.05TH.20
# 2301                    Income share held by lowest 10%        SI.DST.FRST.10
# 2567                    Income share held by lowest 20%        SI.DST.FRST.20
# 2833                    Income share held by second 20%        SI.DST.02ND.20
# 3099                     Income share held by third 20%        SI.DST.03RD.20
#
#        country country_code          2015          2016          2017  \
# 173   Slovakia          SVK  2.650000e+01  2.520000e+01  2.320000e+01
# 439   Slovakia          SVK  3.932503e+00  1.044103e+00  3.417735e+00
# 705   Slovakia          SVK  3.833779e+00  9.139184e-01  3.257376e+00
# 971   Slovakia          SVK  7.126825e+10  7.175913e+10  7.704798e+10
# 1237  Slovakia          SVK  1.313991e+04  1.326000e+04  1.369193e+04
# 1503  Slovakia          SVK  2.320000e+01  2.320000e+01  2.350000e+01
# 1769  Slovakia          SVK  2.090000e+01  1.990000e+01  1.840000e+01
# 2035  Slovakia          SVK  3.500000e+01  3.400000e+01  3.260000e+01
# 2301  Slovakia          SVK  3.000000e+00  2.900000e+00  3.500000e+00
# 2567  Slovakia          SVK  8.500000e+00  8.700000e+00  9.400000e+00
# 2833  Slovakia          SVK  1.460000e+01  1.510000e+01  1.540000e+01
# 3099  Slovakia          SVK  1.870000e+01  1.900000e+01  1.910000e+01
#
#               2018          2019
# 173   2.500000e+01  2.320000e+01
# 439   4.079154e+00  1.737313e+00
# 705   3.935096e+00  1.599727e+00
# 971   8.602506e+10  8.524088e+10
# 1237  1.423072e+04  1.445837e+04
# 1503  2.350000e+01  2.320000e+01
# 1769  1.960000e+01  1.880000e+01
# 2035  3.380000e+01  3.280000e+01
# 2301  3.200000e+00  3.600000e+00
# 2567  8.800000e+00  9.500000e+00
# 2833  1.500000e+01  1.540000e+01
# 3099  1.880000e+01  1.900000e+01

# %%
#changing the values of the countries that are the same, but have a different spelling (Checking for false positives)
gini_income.loc[gini_income['country'].str.contains('Turk')]


#using change country value
gini_income['country'] = gini_income['country'].str.replace('Turkiye', 'Turkey', regex=False)
gini_income.loc[gini_income['country'].str.contains('Turk')]
# Out:
#                                 income_indicator income_indicator_code  \
# 198                                   Gini index           SI.POV.GINI
# 996   Adjusted net national income (current US$)        NY.ADJ.NNTY.CD
# 998   Adjusted net national income (current US$)        NY.ADJ.NNTY.CD
# 1528             Income share held by fourth 20%        SI.DST.04TH.20
# 1794            Income share held by highest 10%        SI.DST.10TH.10
# 2060            Income share held by highest 20%        SI.DST.05TH.20
# 2326             Income share held by lowest 10%        SI.DST.FRST.10
# 2592             Income share held by lowest 20%        SI.DST.FRST.20
# 2858             Income share held by second 20%        SI.DST.02ND.20
# 3124              Income share held by third 20%        SI.DST.03RD.20
#
#                        country country_code          2015          2016  \
# 198                     Turkey          TUR  4.290000e+01  4.190000e+01
# 996                     Turkey          TUR  7.274280e+11  7.293054e+11
# 998   Turks and Caicos Islands          TCA  8.613092e+08  9.443512e+08
# 1528                    Turkey          TUR  2.110000e+01  2.160000e+01
# 1794                    Turkey          TUR  3.350000e+01  3.210000e+01
# 2060                    Turkey          TUR  4.920000e+01  4.830000e+01
# 2326                    Turkey          TUR  2.100000e+00  2.200000e+00
# 2592                    Turkey          TUR  5.600000e+00  5.700000e+00
# 2858                    Turkey          TUR  9.900000e+00  9.900000e+00
# 3124                    Turkey          TUR  1.420000e+01  1.450000e+01
#
#               2017          2018          2019
# 198   4.140000e+01  4.190000e+01  4.190000e+01
# 996   7.166803e+11  6.579581e+11  6.318509e+11
# 998   9.138557e+08  9.780331e+08  1.049836e+09
# 1528  2.150000e+01  2.110000e+01  2.180000e+01
# 1794  3.190000e+01  3.260000e+01  3.160000e+01
# 2060  4.790000e+01  4.850000e+01  4.800000e+01
# 2326  2.200000e+00  2.200000e+00  2.000000e+00
# 2592  5.800000e+00  5.800000e+00  5.400000e+00
# 2858  1.020000e+01  1.010000e+01  1.010000e+01
# 3124  1.460000e+01  1.450000e+01  1.460000e+01

# %%
#running the set operation a second time
gini_countries = set(gini_income['country'].values)
happy_countries = set(happy_master_df['country'].values)

non_matches = gini_countries ^ happy_countries

#remoing countries in no_matches from the dataframes
non_matches = list(non_matches)
print(non_matches)

gini_income = gini_income.loc[~gini_income['country'].isin(non_matches)]
happy_master_df = happy_master_df.loc[~happy_master_df['country'].isin(non_matches)]
# Out:
# ['IDA only', 'Solomon Islands', 'East Asia & Pacific (excluding high income)', 'Sub-Saharan Africa (excluding high income)', 'Dominica', 'St. Vincent and the Grenadines', 'South Korea', 'IBRD only', 'Gambia, The', 'Latin America & Caribbean', 'Barbados', 'Taiwan', 'Somalia', 'Egypt, Arab Rep.', 'Pacific island small states', 'Eswatini', 'Other small states', 'Africa Eastern and Southern', 'Low income', 'Early-demographic dividend', 'Pre-demographic dividend', 'Angola', 'Oman', 'North America', 'Arab World', 'Sao Tome and Principe', 'Lower middle income', 'Lao PDR', 'Lesotho', 'Djibouti', 'East Asia & Pacific (IDA & IBRD countries)', 'Middle East & North Africa (excluding high income)', 'Palestinian Territories', 'Micronesia, Fed. Sts.', 'Fragile and conflict affected situations', 'Central African Republic', 'Hong Kong', 'Turkmenistan', 'Europe & Central Asia', 'Least developed countries: UN classification', 'Seychelles', 'Ivory Coast', 'Congo (Kinshasa)', 'Cabo Verde', 'Namibia', 'Kiribati', 'Middle income', 'East Asia & Pacific', 'Timor-Leste', 'Mozambique', 'United Arab Emirates', 'United Kingdom', 'Sub-Saharan Africa', 'Turks and Caicos Islands', 'Egypt', 'Africa Western and Central', 'Late-demographic dividend', 'Small states', 'Syria', 'Papua New Guinea', 'Central Europe and the Baltics', 'Trinidad and Tobago', 'Kosovo', 'Euro area', 'South Asia (IDA & IBRD)', 'St. Lucia', 'Tonga', 'Belize', 'IDA & IBRD total', 'Latin America & Caribbean (excluding high income)', 'OECD members', 'Congo, Rep.', 'Latin America & the Caribbean (IDA & IBRD countries)', 'Caribbean small states', 'Post-demographic dividend', 'South Asia', 'Fiji', 'Guinea-Bissau', 'High income', 'Maldives', 'Guyana', 'Europe & Central Asia (IDA & IBRD countries)', 'North Macedonia', 'Vanuatu', 'IDA blend', 'Europe & Central Asia (excluding high income)', 'Samoa', 'Upper middle income', 'European Union', 'Heavily indebted poor countries (HIPC)', 'Comoros', 'Equatorial Guinea', 'Korea, Rep.', "Cote d'Ivoire", 'Suriname', 'IDA total', 'Middle East & North Africa', 'Sub-Saharan Africa (IDA & IBRD countries)', 'Congo, Dem. Rep.', 'Middle East & North Africa (IDA & IBRD countries)', 'Venezuela', 'Sudan', 'Bahamas, The', 'Low & middle income', 'Yemen', 'Congo (Brazzaville)', 'World', 'Brunei Darussalam']

# %%
#running set operation one last time to make sure that rows are the same
gini_countries = set(gini_income['country'].values)
happy_countries = set(happy_master_df['country'].values)

non_matches = gini_countries ^ happy_countries

print(non_matches,len(gini_countries), len(happy_countries))
# Out:
# set() 128 128

# %%
gini_income.head()
# Out:
#    income_indicator income_indicator_code  country country_code  2015  2016  \
# 1        Gini index           SI.POV.GINI  Albania          ALB  32.8  33.7
# 8        Gini index           SI.POV.GINI  Armenia          ARM  32.4  32.5
# 11       Gini index           SI.POV.GINI  Austria          AUT  30.5  30.8
# 17       Gini index           SI.POV.GINI  Belarus          BLR  25.6  25.3
# 18       Gini index           SI.POV.GINI  Belgium          BEL  27.7  27.6
#
#     2017  2018  2019
# 1   33.1  30.1  30.8
# 8   33.6  34.4  29.9
# 11  29.7  30.8  30.2
# 17  25.4  25.2  25.3
# 18  27.4  27.2  27.2

# %% [markdown]
# ## Turn years into row columns

# %%
#turning the 2015, 2016, 2017, 2018 columns into years using melt
gini_income= gini_income.melt(
    id_vars=["income_indicator", "country"],
    value_vars=['2015', '2016', '2017','2018','2019'],
    var_name="year"
)

gini_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   income_indicator  4340 non-null   object
#  1   country           4340 non-null   object
#  2   year              4340 non-null   object
#  3   value             4340 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 135.8+ KB

# %%
#changing name of value column to make it clearer
columns = list(gini_income.columns)
columns[-1] = 'income_indicator_value'

gini_income.columns = columns

gini_income.columns
# Out:
# Index(['income_indicator', 'country', 'year', 'income_indicator_value'], dtype='object')

# %%
#converting year column to int datatype
gini_income['year'] =  gini_income['year'].astype(int)

gini_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   income_indicator        4340 non-null   object
#  1   country                 4340 non-null   object
#  2   year                    4340 non-null   int32
#  3   income_indicator_value  4340 non-null   float64
# dtypes: float64(1), int32(1), object(2)
# memory usage: 118.8+ KB

# %%
gini_income.head()
# Out:
#   income_indicator  country  year  income_indicator_value
# 0       Gini index  Albania  2015                    32.8
# 1       Gini index  Armenia  2015                    32.4
# 2       Gini index  Austria  2015                    30.5
# 3       Gini index  Belarus  2015                    25.6
# 4       Gini index  Belgium  2015                    27.7

# %%
happy_master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 640 entries, 0 to 709
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      640 non-null    object
#  1   year                         640 non-null    int32
#  2   happiness_rank               640 non-null    float64
#  3   happiness_score              640 non-null    float64
#  4   gdp_per_capita               640 non-null    float64
#  5   family_social_support        640 non-null    float64
#  6   health_life_expectancy       640 non-null    float64
#  7   freedom                      640 non-null    float64
#  8   trust_government_corruption  640 non-null    float64
#  9   generosity                   640 non-null    float64
# dtypes: float64(8), int32(1), object(1)
# memory usage: 52.5+ KB

# %%
#making copies of each dataframe before combining them
clean_happy_df = happy_master_df.copy()
clean_gini_income = gini_income.copy()

# %%
#merging happy_master_df and gini_income dataframes
happy_gi_df = happy_master_df.merge(right=gini_income,how='inner',on=['country','year'])
happy_gi_df.head()
# Out:
#        country  year  happiness_rank  happiness_score  gdp_per_capita  \
# 0  Switzerland  2015             1.0            7.587         1.39651
# 1  Switzerland  2015             1.0            7.587         1.39651
# 2  Switzerland  2015             1.0            7.587         1.39651
# 3  Switzerland  2015             1.0            7.587         1.39651
# 4      Iceland  2015             2.0            7.561         1.30232
#
#    family_social_support  health_life_expectancy  freedom  \
# 0                1.34951                 0.94143  0.66557
# 1                1.34951                 0.94143  0.66557
# 2                1.34951                 0.94143  0.66557
# 3                1.34951                 0.94143  0.66557
# 4                1.40223                 0.94784  0.62877
#
#    trust_government_corruption  generosity  \
# 0                      0.41978     0.29678
# 1                      0.41978     0.29678
# 2                      0.41978     0.29678
# 3                      0.41978     0.29678
# 4                      0.14145     0.43630
#
#                                     income_indicator  income_indicator_value
# 0     Adjusted net national income (annual % growth)            3.827790e+00
# 1  Adjusted net national income per capita (annua...            2.652581e+00
# 2         Adjusted net national income (current US$)            5.563605e+11
# 3  Adjusted net national income per capita (const...            6.717386e+04
# 4     Adjusted net national income (annual % growth)            8.618972e+00

# %%
happy_gi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4340 entries, 0 to 4339
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      4340 non-null   object
#  1   year                         4340 non-null   int32
#  2   happiness_rank               4340 non-null   float64
#  3   happiness_score              4340 non-null   float64
#  4   gdp_per_capita               4340 non-null   float64
#  5   family_social_support        4340 non-null   float64
#  6   health_life_expectancy       4340 non-null   float64
#  7   freedom                      4340 non-null   float64
#  8   trust_government_corruption  4340 non-null   float64
#  9   generosity                   4340 non-null   float64
#  10  income_indicator             4340 non-null   object
#  11  income_indicator_value       4340 non-null   float64
# dtypes: float64(9), int32(1), object(2)
# memory usage: 423.8+ KB

# %%
#dropping any countries that don't have a gini index value
gini_countries = (
    list(
        set(
            happy_gi_df
            .loc[happy_gi_df['income_indicator'] == 'Gini index']['country']
            .sort_values()
        )
    )
)

happy_gi_df = happy_gi_df.loc[happy_gi_df['country'].isin(gini_countries)]
happy_gi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2995 entries, 8 to 4311
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      2995 non-null   object
#  1   year                         2995 non-null   int32
#  2   happiness_rank               2995 non-null   float64
#  3   happiness_score              2995 non-null   float64
#  4   gdp_per_capita               2995 non-null   float64
#  5   family_social_support        2995 non-null   float64
#  6   health_life_expectancy       2995 non-null   float64
#  7   freedom                      2995 non-null   float64
#  8   trust_government_corruption  2995 non-null   float64
#  9   generosity                   2995 non-null   float64
#  10  income_indicator             2995 non-null   object
#  11  income_indicator_value       2995 non-null   float64
# dtypes: float64(9), int32(1), object(2)
# memory usage: 292.5+ KB

# %%
#also dropping countries that do not have data on all of the other income indicators
happy_gi_df['country'].value_counts()
# Out:
# Denmark               60
# Norway                60
# Belarus               60
# Croatia               60
# Russia                60
# Cyprus                60
# Estonia               60
# Indonesia             60
# Kyrgyzstan            60
# China                 60
# Romania               60
# Serbia                60
# Portugal              60
# Latvia                60
# Albania               60
# Dominican Republic    60
# Greece                60
# Hungary               60
# Honduras              60
# Ukraine               60
# India                 60
# Armenia               60
# Georgia               60
# Peru                  60
# Lithuania             60
# Slovenia              60
# Paraguay              60
# Finland               60
# Netherlands           60
# Sweden                60
# Costa Rica            60
# Austria               60
# United States         60
# Brazil                60
# Luxembourg            60
# Belgium               60
# Panama                60
# Czech Republic        60
# Uruguay               60
# Colombia              60
# Spain                 60
# El Salvador           60
# Slovakia              60
# Ecuador               60
# Bolivia               60
# Moldova               60
# Bulgaria              60
# Thailand              45
# Turkey                45
# Iran                  45
# Malta                 40
# Name: country, dtype: int64

# %%
#creating list of countries that do not have all income indicators for all years
remove_countries = happy_gi_df['country'].value_counts().where(lambda x : x!=60).dropna().index

#creating new dataframe
clean_happy_gi_df = happy_gi_df.loc[~happy_gi_df['country'].isin(remove_countries)]
clean_happy_gi_df['country'].value_counts()
# Out:
# Denmark               60
# Portugal              60
# Croatia               60
# Russia                60
# Cyprus                60
# Estonia               60
# Indonesia             60
# Kyrgyzstan            60
# China                 60
# Romania               60
# Serbia                60
# Latvia                60
# Peru                  60
# Albania               60
# Dominican Republic    60
# Greece                60
# Hungary               60
# Honduras              60
# Ukraine               60
# India                 60
# Armenia               60
# Georgia               60
# Belarus               60
# Lithuania             60
# Norway                60
# Panama                60
# Finland               60
# Netherlands           60
# Sweden                60
# Costa Rica            60
# Austria               60
# United States         60
# Brazil                60
# Luxembourg            60
# Belgium               60
# Czech Republic        60
# Slovenia              60
# Uruguay               60
# Colombia              60
# Spain                 60
# El Salvador           60
# Slovakia              60
# Ecuador               60
# Bolivia               60
# Moldova               60
# Paraguay              60
# Bulgaria              60
# Name: country, dtype: int64

# %%
clean_happy_gi_df.head()
# Out:
#     country  year  happiness_rank  happiness_score  gdp_per_capita  \
# 8   Denmark  2015             3.0            7.527         1.32548
# 9   Denmark  2015             3.0            7.527         1.32548
# 10  Denmark  2015             3.0            7.527         1.32548
# 11  Denmark  2015             3.0            7.527         1.32548
# 12  Denmark  2015             3.0            7.527         1.32548
#
#     family_social_support  health_life_expectancy  freedom  \
# 8                 1.36058                 0.87464  0.64938
# 9                 1.36058                 0.87464  0.64938
# 10                1.36058                 0.87464  0.64938
# 11                1.36058                 0.87464  0.64938
# 12                1.36058                 0.87464  0.64938
#
#     trust_government_corruption  generosity  \
# 8                       0.48357     0.34139
# 9                       0.48357     0.34139
# 10                      0.48357     0.34139
# 11                      0.48357     0.34139
# 12                      0.48357     0.34139
#
#                                      income_indicator  income_indicator_value
# 8                                          Gini index            2.820000e+01
# 9      Adjusted net national income (annual % growth)            2.584901e+00
# 10  Adjusted net national income per capita (annua...            1.862770e+00
# 11         Adjusted net national income (current US$)            2.602355e+11
# 12  Adjusted net national income per capita (const...            4.578804e+04

# %%
#reindexing rows
clean_happy_gi_df.reset_index(inplace=True, drop=True)
clean_happy_gi_df.head()
# Out:
#    country  year  happiness_rank  happiness_score  gdp_per_capita  \
# 0  Denmark  2015             3.0            7.527         1.32548
# 1  Denmark  2015             3.0            7.527         1.32548
# 2  Denmark  2015             3.0            7.527         1.32548
# 3  Denmark  2015             3.0            7.527         1.32548
# 4  Denmark  2015             3.0            7.527         1.32548
#
#    family_social_support  health_life_expectancy  freedom  \
# 0                1.36058                 0.87464  0.64938
# 1                1.36058                 0.87464  0.64938
# 2                1.36058                 0.87464  0.64938
# 3                1.36058                 0.87464  0.64938
# 4                1.36058                 0.87464  0.64938
#
#    trust_government_corruption  generosity  \
# 0                      0.48357     0.34139
# 1                      0.48357     0.34139
# 2                      0.48357     0.34139
# 3                      0.48357     0.34139
# 4                      0.48357     0.34139
#
#                                     income_indicator  income_indicator_value
# 0                                         Gini index            2.820000e+01
# 1     Adjusted net national income (annual % growth)            2.584901e+00
# 2  Adjusted net national income per capita (annua...            1.862770e+00
# 3         Adjusted net national income (current US$)            2.602355e+11
# 4  Adjusted net national income per capita (const...            4.578804e+04

# %%
#All data cleaning done!
clean_happy_gi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2820 entries, 0 to 2819
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      2820 non-null   object
#  1   year                         2820 non-null   int32
#  2   happiness_rank               2820 non-null   float64
#  3   happiness_score              2820 non-null   float64
#  4   gdp_per_capita               2820 non-null   float64
#  5   family_social_support        2820 non-null   float64
#  6   health_life_expectancy       2820 non-null   float64
#  7   freedom                      2820 non-null   float64
#  8   trust_government_corruption  2820 non-null   float64
#  9   generosity                   2820 non-null   float64
#  10  income_indicator             2820 non-null   object
#  11  income_indicator_value       2820 non-null   float64
# dtypes: float64(9), int32(1), object(2)
# memory usage: 253.5+ KB

# %%
#number of countries being analyzed in the combined clean_happy_gi_df dataframe
print(len(set(clean_happy_gi_df['country'])))
print(set(clean_happy_gi_df['country']))
# Out:
# 47
# {'Estonia', 'Ukraine', 'El Salvador', 'Indonesia', 'Uruguay', 'Spain', 'Latvia', 'Serbia', 'Honduras', 'Georgia', 'Cyprus', 'Austria', 'Netherlands', 'Denmark', 'Finland', 'Belarus', 'Kyrgyzstan', 'Brazil', 'Romania', 'Greece', 'Costa Rica', 'Moldova', 'Norway', 'Albania', 'Czech Republic', 'Armenia', 'Belgium', 'Croatia', 'Panama', 'Colombia', 'Russia', 'Sweden', 'Bolivia', 'China', 'Paraguay', 'Ecuador', 'Hungary', 'Bulgaria', 'India', 'Peru', 'Lithuania', 'Luxembourg', 'Portugal', 'Slovakia', 'United States', 'Slovenia', 'Dominican Republic'}

# %% [markdown]
# ## Exploratory Data Analysis
#
# This section will include EDA on the clean_happy_gi_df, clean_happy_df, and the clean_gini_income dataframes.

# %%
#premlinary look at the dataframe
clean_happy_df.describe()
# Out:
#              year  happiness_rank  happiness_score  gdp_per_capita  \
# count   640.00000      640.000000       640.000000      640.000000
# mean   2017.00000       75.248437         5.468887        0.938401
# std       1.41532       44.996670         1.121901        0.394866
# min    2015.00000        1.000000         2.839000        0.015300
# 25%    2016.00000       36.000000         4.571000        0.647590
# 50%    2017.00000       74.000000         5.429500        1.008205
# 75%    2018.00000      114.000000         6.321250        1.245887
# max    2019.00000      158.000000         7.769000        1.870766
#
#        family_social_support  health_life_expectancy     freedom  \
# count             640.000000              640.000000  640.000000
# mean                1.103532                0.637336    0.423692
# std                 0.322226                0.231909    0.146231
# min                 0.000000                0.000000    0.000000
# 25%                 0.891645                0.500298    0.326542
# 50%                 1.150556                0.674500    0.439000
# 75%                 1.365250                0.814468    0.539828
# max                 1.644000                1.141000    0.724000
#
#        trust_government_corruption  generosity
# count                   640.000000  640.000000
# mean                      0.124371    0.218780
# std                       0.108518    0.125398
# min                       0.000000    0.000000
# 25%                       0.051280    0.130000
# 50%                       0.088950    0.201835
# 75%                       0.153645    0.283616
# max                       0.551910    0.838075

# %%
#top 10 happiest countries based on happiness_rank
data = clean_happy_gi_df.groupby(by=['country'])['happiness_rank'].mean().sort_values()[:10]
plt.figure(figsize=(10,8))
ax = sns.barplot(x=data.index, y=data, palette="crest")
plt.xlabel('Country')
plt.ylabel('Happiness Rank')
plt.xticks(rotation=45)
plt.bar_label(container=ax.containers[0], labels=data.values)
plt.title("Average Happiness Rankings From 2015 - 2019: Top Ten Happiest Countries");

# %%
#10 least happiest countries based on happiness_rank
data = clean_happy_gi_df.groupby(by=['country'])['happiness_rank'].mean().sort_values(ascending=False)[:10]
plt.figure(figsize=(10,8))
ax = sns.barplot(x=data.index, y=data, palette="crest")
plt.xlabel('Country')
plt.ylabel('Happiness Rank')
plt.xticks(rotation=45)
plt.bar_label(container=ax.containers[0], labels=data.values)
plt.title("Average Happiness Rankings From 2015 - 2019: Ten Least Happiest Countries");

# %%
#Pulling top 5 happiest countries, the 5 least happiness countries
data = clean_happy_gi_df.groupby(by=['country'])['happiness_rank'].mean().sort_values()

#list to hold hold the targeted countries 
countries = []

#adding the happiest countries
countries.extend(list(data.index[:5]))

#adding 5 of the least happiest countries
countries.extend(list(data.index[-5:]))
print(countries)
# Out:
# ['Denmark', 'Norway', 'Finland', 'Netherlands', 'Sweden', 'Bulgaria', 'Armenia', 'Georgia', 'India', 'Ukraine']

# %% [markdown]
# ## +Reminder:The Gini index ranges from 0 (perfect equality) to 100 (complete inequality). +

# %%
#creating dataframe of happiness rank and gini index
data = (
    clean_happy_gi_df
    .loc[(clean_happy_gi_df['income_indicator'] == 'Gini index') & (clean_happy_gi_df['country'].isin(countries))]
    .groupby(by=['country','year'])['happiness_rank', 'income_indicator_value']
    .mean()
)

data
# Out:
# C:\Users\wilks\AppData\Local\Temp\ipykernel_16796\1165928590.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   clean_happy_gi_df
#                   happiness_rank  income_indicator_value
# country     year
# Armenia     2015           127.0                    32.4
#             2016           121.0                    32.5
#             2017           121.0                    33.6
#             2018           129.0                    34.4
#             2019           116.0                    29.9
# Bulgaria    2015           134.0                    38.6
#             2016           129.0                    40.6
#             2017           105.0                    40.4
#             2018           100.0                    41.3
#             2019            97.0                    40.3
# Denmark     2015             3.0                    28.2
#             2016             1.0                    28.2
#             2017             2.0                    28.7
#             2018             3.0                    28.2
#             2019             2.0                    27.7
# Finland     2015             6.0                    27.1
#             2016             5.0                    27.1
#             2017             5.0                    27.4
#             2018             1.0                    27.3
#             2019             1.0                    27.7
# Georgia     2015           130.0                    36.5
#             2016           126.0                    36.6
#             2017           125.0                    37.9
#             2018           128.0                    36.4
#             2019           119.0                    35.9
# India       2015           117.0                    34.7
#             2016           118.0                    34.8
#             2017           122.0                    35.9
#             2018           133.0                    34.6
#             2019           140.0                    35.7
# Netherlands 2015             7.0                    28.2
#             2016             7.0                    28.2
#             2017             6.0                    28.5
#             2018             6.0                    28.1
#             2019             5.0                    29.2
# Norway      2015             4.0                    27.5
#             2016             4.0                    28.5
#             2017             1.0                    27.0
#             2018             2.0                    27.6
#             2019             3.0                    27.7
# Sweden      2015             8.0                    29.2
#             2016            10.0                    29.6
#             2017             9.0                    28.8
#             2018             9.0                    30.0
#             2019             7.0                    29.3
# Ukraine     2015           111.0                    25.5
#             2016           123.0                    25.0
#             2017           132.0                    26.0
#             2018           138.0                    26.1
#             2019           133.0                    26.6

# %%
data = data.reset_index()

# %%
ax = sns.pairplot(data)

# %%
data.corr()
# Out:
#                             year  happiness_rank  income_indicator_value
# year                    1.000000       -0.010193                0.021912
# happiness_rank         -0.010193        1.000000                0.608070
# income_indicator_value  0.021912        0.608070                1.000000

# %%
sns.heatmap(data=data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#correlation matrix of clean_happy_gi_df by year
data = clean_happy_gi_df.loc[clean_happy_gi_df['income_indicator'] == 'Gini index'].groupby(by=['year']).corr()
data
# Out:
#                                   happiness_rank  happiness_score  \
# year
# 2015 happiness_rank                     1.000000        -0.990232
#      happiness_score                   -0.990232         1.000000
#      gdp_per_capita                    -0.568843         0.605838
#      family_social_support             -0.663859         0.647536
#      health_life_expectancy            -0.467713         0.505384
#      freedom                           -0.697865         0.715743
#      trust_government_corruption       -0.536525         0.603360
#      generosity                        -0.467941         0.497469
#      income_indicator_value             0.033969        -0.056930
# 2016 happiness_rank                     1.000000        -0.995112
#      happiness_score                   -0.995112         1.000000
#      gdp_per_capita                    -0.629519         0.653978
#      family_social_support             -0.667452         0.665430
#      health_life_expectancy            -0.489452         0.522316
#      freedom                           -0.691601         0.703534
#      trust_government_corruption       -0.578593         0.623874
#      generosity                        -0.406027         0.431252
#      income_indicator_value             0.034316        -0.050289
# 2017 happiness_rank                     1.000000        -0.990896
#      happiness_score                   -0.990896         1.000000
#      gdp_per_capita                    -0.672516         0.684608
#      family_social_support             -0.647346         0.640997
#      health_life_expectancy            -0.518128         0.546593
#      freedom                           -0.634981         0.668530
#      trust_government_corruption       -0.571947         0.640492
#      generosity                        -0.278113         0.334994
#      income_indicator_value             0.032219        -0.063816
# 2018 happiness_rank                     1.000000        -0.987853
#      happiness_score                   -0.987853         1.000000
#      gdp_per_capita                    -0.675938         0.697524
#      family_social_support             -0.693601         0.675964
#      health_life_expectancy            -0.605249         0.623112
#      freedom                           -0.600461         0.626822
#      trust_government_corruption       -0.568419         0.659523
#      generosity                        -0.269067         0.346909
#      income_indicator_value            -0.011593        -0.051616
# 2019 happiness_rank                     1.000000        -0.984446
#      happiness_score                   -0.984446         1.000000
#      gdp_per_capita                    -0.673987         0.694234
#      family_social_support             -0.699799         0.685428
#      health_life_expectancy            -0.682424         0.694676
#      freedom                           -0.511399         0.549823
#      trust_government_corruption       -0.584483         0.681874
#      generosity                        -0.174107         0.246601
#      income_indicator_value            -0.003930        -0.059774
#
#                                   gdp_per_capita  family_social_support  \
# year
# 2015 happiness_rank                    -0.568843              -0.663859
#      happiness_score                    0.605838               0.647536
#      gdp_per_capita                     1.000000               0.545747
#      family_social_support              0.545747               1.000000
#      health_life_expectancy             0.810000               0.400788
#      freedom                            0.357746               0.457532
#      trust_government_corruption        0.461686               0.221132
#      generosity                         0.199056               0.320215
#      income_indicator_value            -0.363901              -0.111967
# 2016 happiness_rank                    -0.629519              -0.667452
#      happiness_score                    0.653978               0.665430
#      gdp_per_capita                     1.000000               0.542408
#      family_social_support              0.542408               1.000000
#      health_life_expectancy             0.818099               0.351489
#      freedom                            0.383135               0.406596
#      trust_government_corruption        0.507543               0.253084
#      generosity                         0.203625               0.261081
#      income_indicator_value            -0.328911              -0.089435
# 2017 happiness_rank                    -0.672516              -0.647346
#      happiness_score                    0.684608               0.640997
#      gdp_per_capita                     1.000000               0.513968
#      family_social_support              0.513968               1.000000
#      health_life_expectancy             0.793688               0.318183
#      freedom                            0.374559               0.340272
#      trust_government_corruption        0.537572               0.261639
#      generosity                         0.126667               0.195709
#      income_indicator_value            -0.334463              -0.129902
# 2018 happiness_rank                    -0.675938              -0.693601
#      happiness_score                    0.697524               0.675964
#      gdp_per_capita                     1.000000               0.533041
#      family_social_support              0.533041               1.000000
#      health_life_expectancy             0.803490               0.393662
#      freedom                            0.344884               0.289411
#      trust_government_corruption        0.547289               0.270481
#      generosity                         0.143743               0.186013
#      income_indicator_value            -0.313154              -0.089254
# 2019 happiness_rank                    -0.673987              -0.699799
#      happiness_score                    0.694234               0.685428
#      gdp_per_capita                     1.000000               0.531769
#      family_social_support              0.531769               1.000000
#      health_life_expectancy             0.755135               0.434908
#      freedom                            0.204078               0.215971
#      trust_government_corruption        0.561424               0.312283
#      generosity                         0.024606               0.109114
#      income_indicator_value            -0.331166              -0.116240
#
#                                   health_life_expectancy   freedom  \
# year
# 2015 happiness_rank                            -0.467713 -0.697865
#      happiness_score                            0.505384  0.715743
#      gdp_per_capita                             0.810000  0.357746
#      family_social_support                      0.400788  0.457532
#      health_life_expectancy                     1.000000  0.335798
#      freedom                                    0.335798  1.000000
#      trust_government_corruption                0.402670  0.633382
#      generosity                                 0.159575  0.621063
#      income_indicator_value                    -0.335123  0.076990
# 2016 happiness_rank                            -0.489452 -0.691601
#      happiness_score                            0.522316  0.703534
#      gdp_per_capita                             0.818099  0.383135
#      family_social_support                      0.351489  0.406596
#      health_life_expectancy                     1.000000  0.316451
#      freedom                                    0.316451  1.000000
#      trust_government_corruption                0.445432  0.622093
#      generosity                                 0.115715  0.537127
#      income_indicator_value                    -0.332831  0.079448
# 2017 happiness_rank                            -0.518128 -0.634981
#      happiness_score                            0.546593  0.668530
#      gdp_per_capita                             0.793688  0.374559
#      family_social_support                      0.318183  0.340272
#      health_life_expectancy                     1.000000  0.288051
#      freedom                                    0.288051  1.000000
#      trust_government_corruption                0.455446  0.594073
#      generosity                                 0.062232  0.436022
#      income_indicator_value                    -0.363174  0.104781
# 2018 happiness_rank                            -0.605249 -0.600461
#      happiness_score                            0.623112  0.626822
#      gdp_per_capita                             0.803490  0.344884
#      family_social_support                      0.393662  0.289411
#      health_life_expectancy                     1.000000  0.296087
#      freedom                                    0.296087  1.000000
#      trust_government_corruption                0.478978  0.585026
#      generosity                                 0.072738  0.434595
#      income_indicator_value                    -0.353335  0.167945
# 2019 happiness_rank                            -0.682424 -0.511399
#      happiness_score                            0.694676  0.549823
#      gdp_per_capita                             0.755135  0.204078
#      family_social_support                      0.434908  0.215971
#      health_life_expectancy                     1.000000  0.270236
#      freedom                                    0.270236  1.000000
#      trust_government_corruption                0.501957  0.545475
#      generosity                                -0.009394  0.439482
#      income_indicator_value                    -0.250814  0.195966
#
#                                   trust_government_corruption  generosity  \
# year
# 2015 happiness_rank                                 -0.536525   -0.467941
#      happiness_score                                 0.603360    0.497469
#      gdp_per_capita                                  0.461686    0.199056
#      family_social_support                           0.221132    0.320215
#      health_life_expectancy                          0.402670    0.159575
#      freedom                                         0.633382    0.621063
#      trust_government_corruption                     1.000000    0.383857
#      generosity                                      0.383857    1.000000
#      income_indicator_value                         -0.212145   -0.039628
# 2016 happiness_rank                                 -0.578593   -0.406027
#      happiness_score                                 0.623874    0.431252
#      gdp_per_capita                                  0.507543    0.203625
#      family_social_support                           0.253084    0.261081
#      health_life_expectancy                          0.445432    0.115715
#      freedom                                         0.622093    0.537127
#      trust_government_corruption                     1.000000    0.392348
#      generosity                                      0.392348    1.000000
#      income_indicator_value                         -0.226484   -0.140521
# 2017 happiness_rank                                 -0.571947   -0.278113
#      happiness_score                                 0.640492    0.334994
#      gdp_per_capita                                  0.537572    0.126667
#      family_social_support                           0.261639    0.195709
#      health_life_expectancy                          0.455446    0.062232
#      freedom                                         0.594073    0.436022
#      trust_government_corruption                     1.000000    0.382250
#      generosity                                      0.382250    1.000000
#      income_indicator_value                         -0.225090   -0.165536
# 2018 happiness_rank                                 -0.568419   -0.269067
#      happiness_score                                 0.659523    0.346909
#      gdp_per_capita                                  0.547289    0.143743
#      family_social_support                           0.270481    0.186013
#      health_life_expectancy                          0.478978    0.072738
#      freedom                                         0.585026    0.434595
#      trust_government_corruption                     1.000000    0.430342
#      generosity                                      0.430342    1.000000
#      income_indicator_value                         -0.226671   -0.169929
# 2019 happiness_rank                                 -0.584483   -0.174107
#      happiness_score                                 0.681874    0.246601
#      gdp_per_capita                                  0.561424    0.024606
#      family_social_support                           0.312283    0.109114
#      health_life_expectancy                          0.501957   -0.009394
#      freedom                                         0.545475    0.439482
#      trust_government_corruption                     1.000000    0.359108
#      generosity                                      0.359108    1.000000
#      income_indicator_value                         -0.230388   -0.103896
#
#                                   income_indicator_value
# year
# 2015 happiness_rank                             0.033969
#      happiness_score                           -0.056930
#      gdp_per_capita                            -0.363901
#      family_social_support                     -0.111967
#      health_life_expectancy                    -0.335123
#      freedom                                    0.076990
#      trust_government_corruption               -0.212145
#      generosity                                -0.039628
#      income_indicator_value                     1.000000
# 2016 happiness_rank                             0.034316
#      happiness_score                           -0.050289
#      gdp_per_capita                            -0.328911
#      family_social_support                     -0.089435
#      health_life_expectancy                    -0.332831
#      freedom                                    0.079448
#      trust_government_corruption               -0.226484
#      generosity                                -0.140521
#      income_indicator_value                     1.000000
# 2017 happiness_rank                             0.032219
#      happiness_score                           -0.063816
#      gdp_per_capita                            -0.334463
#      family_social_support                     -0.129902
#      health_life_expectancy                    -0.363174
#      freedom                                    0.104781
#      trust_government_corruption               -0.225090
#      generosity                                -0.165536
#      income_indicator_value                     1.000000
# 2018 happiness_rank                            -0.011593
#      happiness_score                           -0.051616
#      gdp_per_capita                            -0.313154
#      family_social_support                     -0.089254
#      health_life_expectancy                    -0.353335
#      freedom                                    0.167945
#      trust_government_corruption               -0.226671
#      generosity                                -0.169929
#      income_indicator_value                     1.000000
# 2019 happiness_rank                            -0.003930
#      happiness_score                           -0.059774
#      gdp_per_capita                            -0.331166
#      family_social_support                     -0.116240
#      health_life_expectancy                    -0.250814
#      freedom                                    0.195966
#      trust_government_corruption               -0.230388
#      generosity                                -0.103896
#      income_indicator_value                     1.000000

# %%
data.reset_index(inplace=True)
data.head()
# Out:
#    year                 level_1  happiness_rank  happiness_score  \
# 0  2015          happiness_rank        1.000000        -0.990232
# 1  2015         happiness_score       -0.990232         1.000000
# 2  2015          gdp_per_capita       -0.568843         0.605838
# 3  2015   family_social_support       -0.663859         0.647536
# 4  2015  health_life_expectancy       -0.467713         0.505384
#
#    gdp_per_capita  family_social_support  health_life_expectancy   freedom  \
# 0       -0.568843              -0.663859               -0.467713 -0.697865
# 1        0.605838               0.647536                0.505384  0.715743
# 2        1.000000               0.545747                0.810000  0.357746
# 3        0.545747               1.000000                0.400788  0.457532
# 4        0.810000               0.400788                1.000000  0.335798
#
#    trust_government_corruption  generosity  income_indicator_value
# 0                    -0.536525   -0.467941                0.033969
# 1                     0.603360    0.497469               -0.056930
# 2                     0.461686    0.199056               -0.363901
# 3                     0.221132    0.320215               -0.111967
# 4                     0.402670    0.159575               -0.335123

# %%
data.corr()
# Out:
#                                  year  happiness_rank  happiness_score  \
# year                         1.000000        0.002849        -0.000115
# happiness_rank               0.002849        1.000000        -0.998230
# happiness_score             -0.000115       -0.998230         1.000000
# gdp_per_capita              -0.019650       -0.871703         0.879621
# family_social_support       -0.029493       -0.908600         0.898831
# health_life_expectancy      -0.007668       -0.813625         0.822942
# freedom                     -0.051431       -0.855200         0.862970
# trust_government_corruption  0.018182       -0.854947         0.880554
# generosity                  -0.076709       -0.537789         0.563917
# income_indicator_value       0.009187        0.332350        -0.366976
#
#                              gdp_per_capita  family_social_support  \
# year                              -0.019650              -0.029493
# happiness_rank                    -0.871703              -0.908600
# happiness_score                    0.879621               0.898831
# gdp_per_capita                     1.000000               0.829338
# family_social_support              0.829338               1.000000
# health_life_expectancy             0.970582               0.746435
# freedom                            0.614143               0.666002
# trust_government_corruption        0.809344               0.668076
# generosity                         0.339572               0.425973
# income_indicator_value            -0.642398              -0.387030
#
#                              health_life_expectancy   freedom  \
# year                                      -0.007668 -0.051431
# happiness_rank                            -0.813625 -0.855200
# happiness_score                            0.822942  0.862970
# gdp_per_capita                             0.970582  0.614143
# family_social_support                      0.746435  0.666002
# health_life_expectancy                     1.000000  0.558427
# freedom                                    0.558427  1.000000
# trust_government_corruption                0.771934  0.832858
# generosity                                 0.271355  0.721330
# income_indicator_value                    -0.650767 -0.153904
#
#                              trust_government_corruption  generosity  \
# year                                            0.018182   -0.076709
# happiness_rank                                 -0.854947   -0.537789
# happiness_score                                 0.880554    0.563917
# gdp_per_capita                                  0.809344    0.339572
# family_social_support                           0.668076    0.425973
# health_life_expectancy                          0.771934    0.271355
# freedom                                         0.832858    0.721330
# trust_government_corruption                     1.000000    0.620521
# generosity                                      0.620521    1.000000
# income_indicator_value                         -0.526042   -0.312175
#
#                              income_indicator_value
# year                                       0.009187
# happiness_rank                             0.332350
# happiness_score                           -0.366976
# gdp_per_capita                            -0.642398
# family_social_support                     -0.387030
# health_life_expectancy                    -0.650767
# freedom                                   -0.153904
# trust_government_corruption               -0.526042
# generosity                                -0.312175
# income_indicator_value                     1.000000

# %%
#correlation matrix of happy_gi_master_df for 2015 (using Ginni index)
(
    clean_happy_gi_df
    .loc[(clean_happy_gi_df['income_indicator'] == 'Gini index') & 
         (clean_happy_gi_df['year'] == 2015) ].drop(columns='year').corr()
)
# Out:
#                              happiness_rank  happiness_score  gdp_per_capita  \
# happiness_rank                     1.000000        -0.990232       -0.568843
# happiness_score                   -0.990232         1.000000        0.605838
# gdp_per_capita                    -0.568843         0.605838        1.000000
# family_social_support             -0.663859         0.647536        0.545747
# health_life_expectancy            -0.467713         0.505384        0.810000
# freedom                           -0.697865         0.715743        0.357746
# trust_government_corruption       -0.536525         0.603360        0.461686
# generosity                        -0.467941         0.497469        0.199056
# income_indicator_value             0.033969        -0.056930       -0.363901
#
#                              family_social_support  health_life_expectancy  \
# happiness_rank                           -0.663859               -0.467713
# happiness_score                           0.647536                0.505384
# gdp_per_capita                            0.545747                0.810000
# family_social_support                     1.000000                0.400788
# health_life_expectancy                    0.400788                1.000000
# freedom                                   0.457532                0.335798
# trust_government_corruption               0.221132                0.402670
# generosity                                0.320215                0.159575
# income_indicator_value                   -0.111967               -0.335123
#
#                               freedom  trust_government_corruption  \
# happiness_rank              -0.697865                    -0.536525
# happiness_score              0.715743                     0.603360
# gdp_per_capita               0.357746                     0.461686
# family_social_support        0.457532                     0.221132
# health_life_expectancy       0.335798                     0.402670
# freedom                      1.000000                     0.633382
# trust_government_corruption  0.633382                     1.000000
# generosity                   0.621063                     0.383857
# income_indicator_value       0.076990                    -0.212145
#
#                              generosity  income_indicator_value
# happiness_rank                -0.467941                0.033969
# happiness_score                0.497469               -0.056930
# gdp_per_capita                 0.199056               -0.363901
# family_social_support          0.320215               -0.111967
# health_life_expectancy         0.159575               -0.335123
# freedom                        0.621063                0.076990
# trust_government_corruption    0.383857               -0.212145
# generosity                     1.000000               -0.039628
# income_indicator_value        -0.039628                1.000000

# %%
#correlation matrix of happy_gi_master_df for 2015 (using Adjusted net national income (current US$))
(
    clean_happy_gi_df
    .loc[(clean_happy_gi_df['income_indicator'] == 'Adjusted net national income (current US$)') & 
         (clean_happy_gi_df['year'] == 2015) ].drop(columns='year').corr()
)
# Out:
#                              happiness_rank  happiness_score  gdp_per_capita  \
# happiness_rank                     1.000000        -0.990232       -0.568843
# happiness_score                   -0.990232         1.000000        0.605838
# gdp_per_capita                    -0.568843         0.605838        1.000000
# family_social_support             -0.663859         0.647536        0.545747
# health_life_expectancy            -0.467713         0.505384        0.810000
# freedom                           -0.697865         0.715743        0.357746
# trust_government_corruption       -0.536525         0.603360        0.461686
# generosity                        -0.467941         0.497469        0.199056
# income_indicator_value            -0.126784         0.138054        0.161458
#
#                              family_social_support  health_life_expectancy  \
# happiness_rank                           -0.663859               -0.467713
# happiness_score                           0.647536                0.505384
# gdp_per_capita                            0.545747                0.810000
# family_social_support                     1.000000                0.400788
# health_life_expectancy                    0.400788                1.000000
# freedom                                   0.457532                0.335798
# trust_government_corruption               0.221132                0.402670
# generosity                                0.320215                0.159575
# income_indicator_value                    0.022857                0.112419
#
#                               freedom  trust_government_corruption  \
# happiness_rank              -0.697865                    -0.536525
# happiness_score              0.715743                     0.603360
# gdp_per_capita               0.357746                     0.461686
# family_social_support        0.457532                     0.221132
# health_life_expectancy       0.335798                     0.402670
# freedom                      1.000000                     0.633382
# trust_government_corruption  0.633382                     1.000000
# generosity                   0.621063                     0.383857
# income_indicator_value       0.137295                    -0.005605
#
#                              generosity  income_indicator_value
# happiness_rank                -0.467941               -0.126784
# happiness_score                0.497469                0.138054
# gdp_per_capita                 0.199056                0.161458
# family_social_support          0.320215                0.022857
# health_life_expectancy         0.159575                0.112419
# freedom                        0.621063                0.137295
# trust_government_corruption    0.383857               -0.005605
# generosity                     1.000000                0.179357
# income_indicator_value         0.179357                1.000000

# %%
#correlation matrix of happy_gi_master_df for 2015 (using Adjusted net national income (annual % growth))
(
    clean_happy_gi_df
    .loc[(clean_happy_gi_df['income_indicator'] == 'Adjusted net national income (annual % growth)') & 
         (clean_happy_gi_df['year'] == 2015) ].drop(columns='year').corr()
)
# Out:
#                              happiness_rank  happiness_score  gdp_per_capita  \
# happiness_rank                     1.000000        -0.990232       -0.568843
# happiness_score                   -0.990232         1.000000        0.605838
# gdp_per_capita                    -0.568843         0.605838        1.000000
# family_social_support             -0.663859         0.647536        0.545747
# health_life_expectancy            -0.467713         0.505384        0.810000
# freedom                           -0.697865         0.715743        0.357746
# trust_government_corruption       -0.536525         0.603360        0.461686
# generosity                        -0.467941         0.497469        0.199056
# income_indicator_value             0.148729        -0.144308       -0.147958
#
#                              family_social_support  health_life_expectancy  \
# happiness_rank                           -0.663859               -0.467713
# happiness_score                           0.647536                0.505384
# gdp_per_capita                            0.545747                0.810000
# family_social_support                     1.000000                0.400788
# health_life_expectancy                    0.400788                1.000000
# freedom                                   0.457532                0.335798
# trust_government_corruption               0.221132                0.402670
# generosity                                0.320215                0.159575
# income_indicator_value                   -0.187988               -0.034390
#
#                               freedom  trust_government_corruption  \
# happiness_rank              -0.697865                    -0.536525
# happiness_score              0.715743                     0.603360
# gdp_per_capita               0.357746                     0.461686
# family_social_support        0.457532                     0.221132
# health_life_expectancy       0.335798                     0.402670
# freedom                      1.000000                     0.633382
# trust_government_corruption  0.633382                     1.000000
# generosity                   0.621063                     0.383857
# income_indicator_value       0.010054                    -0.205655
#
#                              generosity  income_indicator_value
# happiness_rank                -0.467941                0.148729
# happiness_score                0.497469               -0.144308
# gdp_per_capita                 0.199056               -0.147958
# family_social_support          0.320215               -0.187988
# health_life_expectancy         0.159575               -0.034390
# freedom                        0.621063                0.010054
# trust_government_corruption    0.383857               -0.205655
# generosity                     1.000000                0.169761
# income_indicator_value         0.169761                1.000000

# %%
#calculating correlation and pvalue of happiness score and gini index with pearsonr method
pearsonr(
    clean_happy_gi_df['happiness_score']
    .loc[(clean_happy_gi_df['income_indicator'] == 'Gini index')], 
    clean_happy_gi_df['income_indicator_value'].loc[(clean_happy_gi_df['income_indicator'] == 'Gini index')]
)
# Out:
# (-0.05804210317238166, 0.37574084972342975)

# %%
#calculating correlation and pvalue of happiness score and Adjusted net national income (current US$) with pearsonr method
pearsonr(
    clean_happy_gi_df['happiness_score']
    .loc[(clean_happy_gi_df['income_indicator'] == 'Adjusted net national income (current US$)')], 
    clean_happy_gi_df['income_indicator_value'].loc[(clean_happy_gi_df['income_indicator'] == 'Adjusted net national income (current US$)')]
)
# Out:
# (0.10549106379871256, 0.10673836919583546)

# %%
#Gross National Income (GNI) is the total amount of money earned by a nation's people and businesses. It is used to measure and track a nation's wealth from year to year. 
#calculating correlation and pvalue of happiness score and Adjusted net national income (annual % growth) with pearsonr method
pearsonr(
    clean_happy_gi_df['happiness_score']
    .loc[(clean_happy_gi_df['income_indicator'] == 'Adjusted net national income (annual % growth)')], 
    clean_happy_gi_df['income_indicator_value'].loc[(clean_happy_gi_df['income_indicator'] == 'Adjusted net national income (annual % growth)')]
)
# Out:
# (-0.2596062041703282, 5.631579673774299e-05)
